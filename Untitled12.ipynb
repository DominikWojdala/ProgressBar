# %%
# %cd /content/drive/MyDrive/Colab Notebooks/Projekt_12
# Out:
# /content/drive/MyDrive/Colab Notebooks/Projekt_12

# %%
# !ls
# Out:
# 'news - 2024-07-18.txt'  'news - 2024-07-19.txt'  'news - 2024-07-22.txt'  'news - 2024-07-23.txt'

# %%
# !git init
